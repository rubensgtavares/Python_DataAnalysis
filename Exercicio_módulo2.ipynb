# %% [markdown]
# # Exercícios do Módulo 2

# %% [markdown]
# ## Questão 1

# %% [markdown]
# ![264061383_10160264671848949_5538054972103959448_n.png](data:image/png;base64,...)

# %% [markdown]
# IMDb Top 10 Charts

# %%
top_10 = [ "The Shawshank Redemption (1994)" ,
           "The Godfather (1972)" , 
           "The Dark Knight (2008)" , 
           "The Godfather Part II (1974)" , 
           "12 Angry Men (1957)" , 
           "Schindler's List (1993)" , 
           "The Lord of the Rings: The Return of the King (2003)" ,
           "Pulp Fiction (1994)" ,
           "The Lord of the Rings: The Fellowship of the Ring (2001)" , 
           "The Good, the Bad and the Ugly (1966)"
           
    
]
print(top_10)
print(len(top_10))
# Out:
# ['The Shawshank Redemption (1994)', 'The Godfather (1972)', 'The Dark Knight (2008)', 'The Godfather Part II (1974)', '12 Angry Men (1957)', "Schindler's List (1993)", 'The Lord of the Rings: The Return of the King (2003)', 'Pulp Fiction (1994)', 'The Lord of the Rings: The Fellowship of the Ring (2001)', 'The Good, the Bad and the Ugly (1966)']
# 10

# %%
top_10pop = top_10.pop(0)
print(top_10pop)
# Out:
# The Shawshank Redemption (1994)

# %%
print(top_10)
# Out:
# ['The Godfather (1972)', 'The Dark Knight (2008)', 'The Godfather Part II (1974)', '12 Angry Men (1957)', "Schindler's List (1993)", 'The Lord of the Rings: The Return of the King (2003)', 'Pulp Fiction (1994)', 'The Lord of the Rings: The Fellowship of the Ring (2001)', 'The Good, the Bad and the Ugly (1966)']

# %%
top_10.insert(1,"The Shawshank Redemption (1994)" )
print(top_10)
# Out:
# ['The Godfather (1972)', 'The Shawshank Redemption (1994)', [...], 'The Dark Knight (2008)', 'The Godfather Part II (1974)', '12 Angry Men (1957)', "Schindler's List (1993)", 'The Lord of the Rings: The Return of the King (2003)', 'Pulp Fiction (1994)', 'The Lord of the Rings: The Fellowship of the Ring (2001)', 'The Good, the Bad and the Ugly (1966)']

# %% [markdown]
# ## Questão 2

# %% [markdown]
# Estamos com um bug em nosso sistema.

# %%
top_10.append("Pulp Fiction (1994")
top_10.append("The Lord of the Rings: The Fellowship of the Ring (2001)")
top_10.append("The Good, the Bad and the Ugly (1966)")
print(top_10)
print(len(top_10))
# Out:
# ['The Shawshank Redemption (1994)', 'The Godfather (1972)', 'The Dark Knight (2008)', 'The Godfather Part II (1974)', '12 Angry Men (1957)', "Schindler's List (1993)", 'The Lord of the Rings: The Return of the King (2003)', 'Pulp Fiction (1994)', 'The Lord of the Rings: The Fellowship of the Ring (2001)', 'The Good, the Bad and the Ugly (1966)', 'Pulp Fiction (1994', 'The Lord of the Rings: The Fellowship of the Ring (2001)', 'The Good, the Bad and the Ugly (1966)', 'Pulp Fiction (1994', 'The Lord of the Rings: The Fellowship of the Ring (2001)', 'The Good, the Bad and the Ugly (1966)', 'Pulp Fiction (1994', 'The Lord of the Rings: The Fellowship of the Ring (2001)', 'The Good, the Bad and the Ugly (1966)']
# 19

# %%
conversao = list(set(top_10))
print(conversao)
print(len(conversao))
# Out:
# ['The Godfather (1972)', 'Pulp Fiction (1994', 'The Dark Knight (2008)', "Schindler's List (1993)", 'The Lord of the Rings: The Return of the King (2003)', 'The Shawshank Redemption (1994)', 'The Lord of the Rings: The Fellowship of the Ring (2001)', '12 Angry Men (1957)', 'Pulp Fiction (1994)', 'The Godfather Part II (1974)', 'The Good, the Bad and the Ugly (1966)']
# 11

# %% [markdown]
# ## Questão 3

# %% [markdown]
# Dicíonário

# %%
top_10 = {"filmes" : { "1" : {"nome" : "The Shawshank Redemption" , "ano" : " (1994)" , "Sinopse" : "Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency."} ,
                      "2" : {"nome" : "The Godfather" , "ano" : "(1972)" , "Sinopse" : "The aging patriarch of an organized crime dynasty in postwar New York City transfers control of his clandestine empire to his reluctant youngest son." } ,
                      "3" : {"nome" : "The Dark Knight " , "ano" : "(2008)" , "Sinopse" : "When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice."} ,
                      "4" : {"nome" : "The Godfather Part II " , "ano" : "(1974)" , "Sinopse" : "The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate."} ,
                      "5" : {"nome" : "12 Angry Men" , "ano" : "(1957)" , "Sinopse" : "The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict."} ,
                      "6" : {"nome" : "Schindler's List" , "ano" : "(1993)" , "Sinopse" : "In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis."} ,
                      "7" : {"nome" : "The Lord of the Rings: The Return of the King" , "ano" : "(2003)" , "Sinopse" : "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring."} ,
                      "8" : {"nome" : "Pulp Fiction" ,"ano" : "(1994)" , "Sinopse" : "The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption."} ,
                      "9" : {"nome" : "The Lord of the Rings: The Fellowship of the Ring" , "ano" : "(2001)" , "Sinopse" : "A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron."} ,
                      "10" : {"nome" : "The Good, the Bad and the Ugly" , "ano" : "(1966)" , "Sinopse" : "A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery."}
}}
print(top_10)
# Out:
# {'filmes': {'1': {'nome': 'The Shawshank Redemption', 'ano': ' (1994)', 'Sinopse': 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.'}, '2': {'nome': 'The Godfather', 'ano': '(1972)', 'Sinopse': 'The aging patriarch of an organized crime dynasty in postwar New York City transfers control of his clandestine empire to his reluctant youngest son.'}, '3': {'nome': 'The Dark Knight ', 'ano': '(2008)', 'Sinopse': 'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.'}, '4': {'nome': 'The Godfather Part II ', 'ano': '(1974)', 'Sinopse': 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.'}, '5': {'nome': '12 Angry Men', 'ano': '(1957)', 'Sinopse': 'The jury in a New York City
# ...
