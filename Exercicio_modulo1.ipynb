# %% [markdown]
# # **Respostas**

# %% [markdown]
# # ***Exercícios Módulo 1***

# %% [markdown]
# ## 1\. Primeiro Exercício

# %%
saudacao = "Olá Mundo!"
print(saudacao)
# Out:
# Olá Mundo!

# %% [markdown]
# ![302e9f27ca5b1dd0d6309ae1f0f19bb2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2\. Segundo Exercício

# %% [markdown]
# | Dia   | Valor Total Vendas | Qtd Total Vendas | Ticket Medio |
# |-------|--------------------|------------------|--------------|
# | 19/01 | (A)                | 3                | 320.52       |
# | 20/01 | 834.47             | (B)              | 119.21       |
# | 23/01 | 15378.12           | 5                | (C)          |

# %%
# (A)
qtv_a = 3
tkt_a = 320.52

vtv_a = qtv_a * tkt_a
print(vtv_a)
# Out:
# 961.56

# %%
# (B)
vtv_b = 834.47
tkt_b = 119.21

qtv_b = vtv_b / tkt_b 
print(qtv_b)
# Out:
# 7.000000000000001

# %%
#(C)
vtv_c = 15378.12
qtv_c = 5

tkt_c = vtv_c / qtv_c 
print(tkt_c)
# Out:
# 3075.6240000000003

# %% [markdown]
# ## 3\. Terceiro Exercício

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

# %%
print(cancao.upper())
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.

# %%
print(cancao.casefold())
# Out:
# roda mundo, roda gigante, roda moinho, roda pião.

# %%
print(cancao.split())
# Out:
# ['Roda', 'mundo,', 'roda', 'gigante,', 'roda', 'moinho,', 'roda', 'pião.']

# %%
print(cancao.format_map(11))
# Out:
# Roda mundo, roda gigante, roda moinho, roda pião.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

# %%
print(noticia)
print(type(noticia))

selic_float = noticia.find('%')
print(selic_float)
selic_conv = noticia.replace(',' , '.')
selic= float(selic_conv[12:16])
print(selic)
print(type(selic))

titulo_selic = "O valor da taxa Selic"
print(titulo_selic)
print(selic)
# Out:
# Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.
# <class 'str'>
# 16
# 2.75
# <class 'float'>
# O valor da taxa Selic
# 2.75

# %%
ano_find = noticia.find("6")
print(ano_find)
ano = int(noticia[62])
print(ano)
print(type(ano))

titulo_ano = 'Quandidade de Anos'
print(titulo_ano)
print(ano)
# Out:
# 62
# 6
# <class 'int'>
# Quandidade de Anos
# 6

# %% [markdown]
# ## 4\. Quarto Exercício

# %%
a = False
b = True

x = not a & b

# %%
a_e_b = a & b
print(a_e_b)

x_resposta = 'Portanto X é'
print(x_resposta)
x = not(a_e_b)
print(x)
# Out:
# False
# Portanto X é
# True
